# %%
import sys
sys.path.append("../src")
import matplotlib.pyplot as plt
import numpy as np
import helper
reload(helper)
plot_images = helper.plot_images
# %matplotlib inline

# %%
ca = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_002/images/conv_out_0000.csv',delimiter=' ')
cb = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_002/images/conv_out_0300.csv',delimiter=' ')
cc = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_002/images/conv_out_0700.csv',delimiter=' ')
wa = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_002/images/conv_weights_0000.csv',delimiter=' ')
wb = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_002/images/conv_weights_0300.csv',delimiter=' ')
wc = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_002/images/conv_weights_0700.csv',delimiter=' ')

# %%
images = []
names = []
images.append(ca); names.append('a')
images.append(cb); names.append('b')
images.append(cc); names.append('c')
# fname = '../graphs/images_low_' + date + '_' + prefix(ID,3) + '.pdf'
fname = None
plot_images(images=images,names=names,range=None,save='../graphs/both_face.pdf')


images = []
names = []
images.append(wa); names.append('a')
images.append(wb); names.append('b')
images.append(wc); names.append('c')
# fname = '../graphs/images_low_' + date + '_' + prefix(ID,3) + '.pdf'
fname = None
plot_images(images=images,names=names,range=(-0.04,0.04),save='../graphs/both_weights.pdf')
# Out:
# save to ../graphs/both_face.pdf
# /usr/lib/python2.7/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# save to ../graphs/both_weights.pdf

# %%
ca = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_003/images/conv_out_0000.csv',delimiter=' ')
cb = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_003/images/conv_out_0300.csv',delimiter=' ')
cc = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_003/images/conv_out_0700.csv',delimiter=' ')
wa = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_003/images/conv_weights_0000.csv',delimiter=' ')
wb = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_003/images/conv_weights_0300.csv',delimiter=' ')
wc = np.loadtxt('/home/luka/v/lm1015-tmp/data/2016_09_08/alpha_003/images/conv_weights_0700.csv',delimiter=' ')

# %%
images = []
names = []
images.append(ca); names.append('a')
images.append(cb); names.append('b')
images.append(cc); names.append('c')
# fname = '../graphs/images_low_' + date + '_' + prefix(ID,3) + '.pdf'
fname = None
plot_images(images=images,names=names,range=None,save='../graphs/class_face.pdf')


images = []
names = []
images.append(wa); names.append('a')
images.append(wb); names.append('b')
images.append(wc); names.append('c')
# fname = '../graphs/images_low_' + date + '_' + prefix(ID,3) + '.pdf'
fname = None
plot_images(images=images,names=names,range=(-0.04,0.04),save='../graphs/class_weights.pdf')
# Out:
# save to ../graphs/class_face.pdf
# save to ../graphs/class_weights.pdf
