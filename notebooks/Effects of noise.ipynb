# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

data = np.loadtxt('notebooks/data/noise.csv',delimiter=',')
x = data[:,0]
early = data[:,1]
final = data[:,2]

plt.figure()
plt.plot(x,early)
plt.plot(x,final)
plt.show()

# %%
cat notebooks/data/noise.csv
# Out:
# 0, 0.02639, 0.02552
# 0.1, 0.02622, 0.02561
# 0.5, 0.02761, 0.02661
# 1, 0.03152, 0.03025
# 2, 0.03602, 0.0311
# 3, 0.03287, 0.03413
