# %%
# Matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# Pathing
import sys
sys.path.append("../src")
from os.path import join
from results import prefix

# Results
import results
reload(results)
print 'Done.'
# Out:
# Done.

# %%
Results = results.Results
ID = 2
date = '2016_07_06'
r = Results(date, ID)
print join('/home/luka/v/lm1015-tmp/data',join(date,prefix(ID,3)))
r.print_config()
# Out:
# Aim:
# Network Search
# /home/luka/v/lm1015-tmp/data/2016_07_06/002
# global
# {'autoencoder': 'basic',
#  'batch_size': 100,
#  'binary_softmax': True,
#  'commit': 'ec5c2d4',
#  'cost_function': 'cross_entropy',
#  'dropout_rate': 1.0,
#  'dump_frames': False,
#  'fc1_neuron_count': 0,
#  'fc2_neuron_count': 0,
#  'fc3_neuron_count': 20,
#  'final_activation': 'softmax',
#  'iterations': 500,
#  'learning_rate': 0.001,
#  'network': 'gudi_test_network_1',
#  'optimizer': 'adam',
#  'path': 'data',
#  'seed': 1,
#  'seed_randomness': True,
#  'threshold': 0.3,
#  'validation_batch_size': 100}
# results
# {'early_stop_iteration': 80}
# crop
# {'crop': [0, 0, 0, 0], 'resize_scale': 0.8}
# weights
# {'bias initial value': 0.01, 'weights initialisation': ['std_dev', 0.001]}
# data
# {'batch_randomisation': True,
#  'dataset': 'disfa',
#  'disfa_au_map': [1, 2, 4, 5, 6, 9, 12, 15, 17, 20, 25, 26],
#  'image_region': 'full',
#  'image_shape': [94, 94],
#  'label_size': 12,
#  'normalisation_between_minus_one_and_one': False,
#  'normalisation_type': 'face',
#  'path': '/vol/lm1015-tmp/data/2016_07_06',
#  'remove_empty_labels': False,
#  'test_subjects': [1, 3, 5, 7, 9, 11, 13, 17, 21, 24, 26, 28, 30, 32],
#  'threshold': 1,
#  'train_subjects': [2, 4, 6, 8, 10, 12, 16, 18, 23, 25, 27, 29, 31],
#  'validation_subjects': [1, 3, 5, 7, 9, 11, 13, 17, 21, 24, 26, 28, 30, 32]}

# %%
r.lmsq()
r.cross()
r.auto()

# %%
r.au('train',smooth=False)
r.au('validation',smooth=False)
# r.roc_plot('final')
# r.roc_plot('early')
# r.test_confusion('early')

# %% [markdown]
# # Test set:

# %%
r.au('test',smooth=False,model='final')
r.au('test',smooth=False,model='early')
# Out:
# Test ROC values for each class:
# (values for p,r,f1 are maximums)
# class	roc	roc	f1	p	r
# 1 	0.73 	fair 	0.36 	0.89 	1.0
# 2 	0.81 	good 	0.49 	0.81 	1.0
# 4 	0.78 	fair 	0.52 	0.57 	1.0
# 5 	0.87 	good 	0.39 	0.67 	1.0
# 6 	0.86 	good 	0.56 	0.83 	1.0
# 9 	0.78 	fair 	0.43 	0.72 	1.0
# 12 	0.93 	great 	0.72 	0.96 	1.0
# 15 	0.71 	fair 	0.18 	0.26 	1.0
# 17 	0.78 	fair 	0.38 	0.58 	1.0
# 20 	0.72 	fair 	0.28 	0.78 	1.0
# 25 	0.85 	good 	0.68 	0.74 	1.0
# 26 	0.76 	fair 	0.49 	0.69 	1.0
# average f1 =  0.456169670558
# average roc =  0.796541895459
# Test ROC values for each class:
# (values for p,r,f1 are maximums)
# class	roc	roc	f1	p	r
# 1 	0.61 	poor 	0.17 	0.9 	1.0
# 2 	0.68 	poor 	0.15 	0.73 	1.0
# 4 	0.68 	poor 	0.4 	0.61 	1.0
# 5 	0.62 	poor 	0.03 	0.1 	1.0
# 6 	0.88 	good 	0.61 	0.96 	1.0
# 9 	0.7 	poor 	0.23 	0.26 	1.0
# 12 	0.94 	great 	0.75 	0.98 	1.0
# 15 	0.77 	fair 	0.32 	0.49 	1.0
# 17 	0.82 	good 	0.47 	0.8 	1.0
# 20 	0.71 	fair 	0.19 	1.0 	1.0
# 25 	0.72 	fair 	0.55 	0.87 	1.0
# 26 	0.69 	poor 	0.39 	0.59 	1.0
# average f1 =  0.355678125043
# average roc =  0.734457251042

# %%
r.test_confusion('final')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  1 threshold:  0.42
# 	[  823 	 2192 	]
# 	[  736 	 64079 	]
# 	roc:	0.73
# 	f1:	0.36
# 	p:	0.53
# 	r:	0.27
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  2 threshold:  0.85
# 	[  590 	 944 	]
# 	[  260 	 66036 	]
# 	roc:	0.81
# 	f1:	0.49
# 	p:	0.69
# 	r:	0.38
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  4 threshold:  0.42
# 	[  5774 	 4669 	]
# 	[  6162 	 51225 	]
# 	roc:	0.78
# 	f1:	0.52
# 	p:	0.48
# 	r:	0.55
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  5 threshold:  0.37
# 	[  205 	 426 	]
# 	[  223 	 66976 	]
# 	roc:	0.87
# 	f1:	0.39
# 	p:	0.48
# 	r:	0.32
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  6 threshold:  0.05
# 	[  7235 	 3405 	]
# 	[  7895 	 49295 	]
# 	roc:	0.86
# 	f1:	0.56
# 	p:	0.48
# 	r:	0.68
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  9 threshold:  0.26
# 	[  2101 	 1993 	]
# 	[  3575 	 60161 	]
# 	roc:	0.78
# 	f1:	0.43
# 	p:	0.37
# 	r:	0.51
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  12 threshold:  0.31
# 	[  9966 	 3937 	]
# 	[  3977 	 49950 	]
# 	roc:	0.93
# 	f1:	0.72
# 	p:	0.71
# 	r:	0.72
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  15 threshold:  0.05
# 	[  850 	 2982 	]
# 	[  4813 	 59185 	]
# 	roc:	0.71
# 	f1:	0.18
# 	p:	0.15
# 	r:	0.22
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  17 threshold:  0.37
# 	[  2280 	 3764 	]
# 	[  3712 	 58074 	]
# 	roc:	0.78
# 	f1:	0.38
# 	p:	0.38
# 	r:	0.38
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  20 threshold:  0.1
# 	[  640 	 2192 	]
# 	[  1165 	 63833 	]
# 	roc:	0.72
# 	f1:	0.28
# 	p:	0.35
# 	r:	0.23
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  25 threshold:  0.95
# 	[  12966 	 7324 	]
# 	[  4629 	 42911 	]
# 	roc:	0.85
# 	f1:	0.68
# 	p:	0.74
# 	r:	0.64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Class  26 threshold:  0.26
# 	[  6742 	 5615 	]
# 	[  8408 	 47065 	]
# 	roc:	0.76
# 	f1:	0.49
# 	p:	0.45
# 	r:	0.55

# %% [markdown]
# ##

# %%
# path = join(join('/home/luka/v/lm1015-tmp/data',join(date,prefix(ID,3))),'results.html')
# !ipython nbconvert --to html results.ipynb
# !cp 'results.html' $path

# %%
data = np.zeros((100,100))
for i in xrange(100):
    for j in xrange(100):
        x = float(i)/100.0
        y = float(j)/100.0
        data[i][j] = -x*np.log(y)

plt.imshow(data)
plt.colorbar()
plt.xlim(-10,110)
plt.ylim(-10,110)
plt.show()
# Out:
# /home/luka/.local/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log
# /home/luka/.local/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: invalid value encountered in double_scalars
